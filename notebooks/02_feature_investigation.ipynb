# %% [markdown]
# # Feature Investigation
#
# **Date:** 2025-11-05
# **Purpose:** Deep dive into specific features and their relationships
#
# ## Objective
# Investigate correlations, feature importance, and interactions between variables.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import sys
sys.path.append('..')

# %matplotlib inline

# %% [markdown]
# ## Feature Correlations

# %%
# Correlation analysis

# %% [markdown]
# ## Feature Engineering Ideas

# %%
# Test new feature combinations
