# %% [markdown]
# # Exploration Template
#
# **Date:** YYYY-MM-DD
# **Author:** Your Name
# **Purpose:** Brief description of exploration goal
#
# ## Objective
# What question are you trying to answer?
#
# ## Approach
# How will you investigate this question?

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Local imports
import sys
sys.path.append('..')
from src.data import loaders
from src.visualization import distributions

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Load your data here
data = None

# %% [markdown]
# ## Exploration

# %%
# Your exploratory code here

# %% [markdown]
# ## Findings
#
# Summarize what you learned:
# - Finding 1
# - Finding 2
#
# ## Next Steps
#
# What should be done next based on these findings?
